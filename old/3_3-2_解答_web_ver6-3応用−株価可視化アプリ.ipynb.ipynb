# %% [markdown]
# # 3webアプリ作成

# %% [markdown]
# 目次：https://docs.google.com/document/d/1eDw9PK5Ft0vImu81e7oERB_q-dZvxbFe8bGetZBgEEg/edit

# %% [markdown]
# ## 3.3 応用実装

# %% [markdown]
# ### 3.3.1 応用アプリ実装の概要：５つのアプリを作る

# %% [markdown]
# ### 3.3.2 応用アプリ実装

# %% [markdown]
# #### ②株価可視化アプリ
#
# >アプリの概要
#
# <img src="pic/img040.png">
#
# デプロイ先：https://kabu-step2-ver6-6ijpoom5ze3.streamlit.app/
#
# >動作を構成してる部品の紹介（APIやライブラリ）
# API
# - yahoo finance
#     - 目的：株価情報をyf.Ticker("銘柄番号")の１行で取得できる
#     - 参考：https://pypi.org/project/yfinance/
#
# ライブラリ
# - streamlit
#     - 目的：株価情報を表示するためのフロントエンドを生成する
# - pandas
#     - 目的：株価APIで得られたデータを扱いやすくするために使う
# - yfinance
#     - 目的：yahoo financeの株価情報取得手段をライブラリとして提供してくれている。
# - altair
#     - 目的：pandsで構造化データになった株価情報のデータ可視化のために使う
#
#
#
# >ライブラリのインストール
#
# ライブラリ
# - streamlit
#     - pip install streamlit
# - pandas
#     - pip install pandas
# - yfinance
#     - pip install yfinance
# - altair
#     - pip install altair
#
# >ライブラリの公式ドキュメントの見方や使い方を説明
#
#
# ライブラリ
#
# - streamlit
#     - インストール方法はget startページで確認
#     - 参考：https://docs.streamlit.io/library/get-started/installation
#     - st.titleなどはコンポーネントページから確認出来る
#     - 参考：https://streamlit.io/components
# - pandas
#     - pd.DataFrame()で使います。
#     - 参考：https://pandas.pydata.org/docs/
# - yfinance
#     - yf.Ticker("銘柄番号")でその銘柄の株価を取得できます。
#     - 東証などのシンボルはhttps://support.yahoo-net.jp/PccFinance/s/article/H000006603で検索できる
#     - 参考：https://pypi.org/project/yfinance/
# - altair
#     - alt.Chartでチャート生成
#     - オプションは.encode()の中に設定していきます。
#     - 参考：https://pypi.org/project/altair/

# %% [markdown]
# >それぞれの機能をjupyterで動く最小限を作る

# %% [markdown]
# 以下がjuptyterにて動く最低限のアプリの流れです。
#
# 1. 作るアプリの全体のコードを把握
# 1. それぞれ機能を解説
#     1. 株価取得
#     1. チャートによる可視化

# %% [markdown]
# 1.全体のコード

# %% [markdown]
# 使うアプリの全体像は下記のようになります。
# これはweb上では動きませんが、手元では動作するアプリです。
#
# 以下のコードの動作の流れ
# 1. 拡張機能であるライブラリをインポート
# 1. 株価データを要求するための準備
#     1. 株価を取得する会社すべてをtickersに代入
#     1. 要求する日付区間をdaysに代入
# 1. 株価データ取得
#     1. tickersを元にyf.Ticker("ここ銘柄")で１つ１つデータ取得
#     1. dfにデータを格納
#     1. dfにtickersにあるすべての企業の株価が格納されている
# 1. 株価データ整理
#     1. 欲しい銘柄だけをcompaniesに代入
#     1. companiesを使って取得した情報の中から情報を抽出
# 1. チャートで可視化
#     1. チャートの表示範囲の値をyminとymaxに代入
#     1. alt.Chartを使って抽出した株価データを可視化

# %%
import streamlit as st # フロントエンドを扱うstreamlitの機能をインポート
import pandas as pd # データフレームを扱う機能をインポート
import yfinance as yf # yahoo financeから株価情報を取得するための機能をインポート
import altair as alt # チャート可視化機能をインポート

#取得する銘柄の名前とキーを変換する一覧を設定
#東証などのシンボルはhttps://support.yahoo-net.jp/PccFinance/s/article/H000006603で検索できる
tickers = {
    'apple': 'AAPL',
    'facebook': 'META',
    'google': 'GOOGL',
    'microsoft': 'MSFT',
    'netflix': 'NFLX',
    'amazon': 'AMZN',
    'TOTO': '5332.T',
    'TOYOTA': '7203.T',
}

print('株価可視化アプリ')
print("こちらは株価可視化ツールです。以下のオプションから表示日数を指定できます。")# サイドバーに表示
print("表示日数選択") # サイドバーに表示

days = 10 # 取得するための日数daysに代入

print(f"過去 {days}日間 の株価") # 取得する日数を表示


def get_data(days, tickers):
    df = pd.DataFrame() # 株価を代入するための空箱を用意

    # 選択した株価の数だけ yf.Tickerでリクエストしてデータを取得する
    for company in tickers.keys():
        tkr = yf.Ticker(tickers[company]) # 設定した銘柄一覧でリクエストの為の7203.Tなどに変換をして、それをyf.Tickerで株価リクエスト
        hist = tkr.history(period=f'{days}d') # スライドバーで指定した日数で取得した情報を絞る
        hist.index = hist.index.strftime('%d %B %Y') # indexを日付のフォーマットに変更
        hist = hist[['Close']] # データを終値だけ抽出
        hist.columns = [company] # データのカラムをyf.Tickerのリクエストした企業名に設定
        hist = hist.T # 欲しい情報が逆なので、転置する
        hist.index.name = 'Name' # indexの名前をNameにする
        df = pd.concat([df, hist]) # 用意した空のデータフレームに設定したhistのデータを結合する
    return df # 返り値としてdfを返す

df = get_data(days, tickers) # リクエストする企業一覧すべてと変換するtickersを引数に株価取得





# 企業名の配列を生成し、companiesに代入
companies = ['google', 'apple','TOYOTA']

data = df.loc[companies] # 取得したデータから抽出するための配列で絞ってdataに代入
print("株価 ", data.sort_index()) # dataにあるindexを表示
data = data.T.reset_index() # dataを抽出して転置

# 企業ごとの別々のカラムにデータを表示する必要ないので企業を１つのカラムに統一
data = pd.melt(data, id_vars=['Date']).rename(
    columns={'value': 'Stock Prices'}
)


# チャートに表示する範囲、それぞれをymin, ymaxに代入
print("株価の範囲指定") # サイドバーに表示
ymin = 0
ymax = 3000

# dataとスライドバーで設定した最大最小値を元にalt.Chartを使って株価チャートを作成
chart = (
    alt.Chart(data)
    .mark_line(opacity=0.8, clip=True)
    .encode(
        x="Date:T",
        y=alt.Y("Stock Prices:Q", stack=None, scale=alt.Scale(domain=[ymin, ymax])),
        color='Name:N'
    )
)

# 作成したチャートをstreamlitで表示
display(chart)
# Out:
# 株価可視化アプリ
# こちらは株価可視化ツールです。以下のオプションから表示日数を指定できます。
# 表示日数選択
# 過去 10日間 の株価
# ---------------------------------------------------------------------------
# YFRateLimitError                          Traceback (most recent call last)
# Cell In[3], line 43
#      40         df = pd.concat([df, hist]) # 用意した空のデータフレームに設定したhistのデータを結合する
#      41     return df # 返り値としてdfを返す
# ---> 43 df = get_data(days, tickers) # リクエストする企業一覧すべてと変換するtickersを引数に株価取得
#      49 # 企業名の配列を生成し、companiesに代入
#      50 companies = ['google', 'apple','TOYOTA']
#
# Cell In[3], line 34, in get_data(days, tickers)
#      32 for company in tickers.keys():
#      33     tkr = yf.Ticker(tickers[company]) # 設定した銘柄一覧でリクエストの為の7203.Tなどに変換をして、それをyf.Tickerで株価リクエスト
# ---> 34     hist = tkr.history(period=f'{days}d') # スライドバーで指定した日数で取得した情報を絞る
#      35     hist.index = hist.index.strftime('%d %B %Y') # indexを日付のフォーマットに変更
#      36     hist = hist[['Close']] # データを終値だけ抽出
#
# File c:\Users\tkhrs\anaconda3\envs\python311\Lib\site-packages\yfinance\utils.py:104, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     101 logger.debug(f'Entering {func.__name__}()')
#     103 with IndentationContext():
# --> 104     result = func(*args, **kwargs)
#     106 logger.debug(f'Exiting {func.__name__}()')
#     107 return result
#
# File c:\Users\tkhrs\anaconda3\envs\python311\Lib\site-packages\yfinance\base.py:81, in TickerBase.history(self, *args, **kwargs)
#      79 @utils.log_indent_decorator
#      80 def history(self, *args, **kwargs) -> pd.DataFrame:
# ---> 81     return self._lazy_load_price_history().history(*args, **kwargs)
#
# File c:\Users\tkhrs\anaconda3\envs\python311\Lib\site-packages\yfinance\base.py:87, in TickerBase._lazy_load_price_history(self)
#      85 def _lazy_load_price_history(self):
#      86     if self._price_history is None:
# ---> 87         self._price_history = PriceHistory(self._data, self.ticker, self._get_ticker_tz(self.proxy, timeout=10))
#      88     return self._price_history
#
# File c:\Users\tkhrs\anaconda3\envs\python311\Lib\site-packages\yfinance\base.py:103, in TickerBase._get_ticker_tz(self, proxy, timeout)
#     100     tz = None
#     102 if tz is None:
# --> 103     tz = self._fetch_ticker_tz(proxy, timeout)
#     105     if utils.is_valid_timezone(tz):
#     106         # info fetch is relatively slow so cache timezone
#     107         c.store(self.ticker, tz)
#
# File c:\Users\tkhrs\anaconda3\envs\python311\Lib\site-packages\yfinance\utils.py:104, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     101 logger.debug(f'Entering {func.__name__}()')
#     103 with IndentationContext():
# --> 104     result = func(*args, **kwargs)
#     106 logger.debug(f'Exiting {func.__name__}()')
#     107 return result
#
# File c:\Users\tkhrs\anaconda3\envs\python311\Lib\site-packages\yfinance\base.py:126, in TickerBase._fetch_ticker_tz(self, proxy, timeout)
#     123 url = f"{_BASE_URL_}/v8/finance/chart/{self.ticker}"
#     125 try:
# --> 126     data = self._data.cache_get(url=url, params=params, proxy=proxy, timeout=timeout)
#     127     data = data.json()
#     128 except YFRateLimitError:
#     129     # Must propagate this
#
# File c:\Users\tkhrs\anaconda3\envs\python311\Lib\site-packages\yfinance\data.py:30, in lru_cache_freezeargs.<locals>.wrapped(*args, **kwargs)
#      28 args = tuple([tuple(arg) if isinstance(arg, list) else arg for arg in args])
#      29 kwargs = {k: tuple(v) if isinstance(v, list) else v for k, v in kwargs.items()}
# ---> 30 return func(*args, **kwargs)
#
# File c:\Users\tkhrs\anaconda3\envs\python311\Lib\site-packages\yfinance\data.py:404, in YfData.cache_get(self, url, user_agent_headers, params, proxy, timeout)
#     401 @lru_cache_freezeargs
#     402 @lru_cache(maxsize=cache_maxsize)
#     403 def cache_get(self, url, user_agent_headers=None, params=None, proxy=None, timeout=30):
# --> 404     return self.get(url, user_agent_headers, params, proxy, timeout)
#
# File c:\Users\tkhrs\anaconda3\envs\python311\Lib\site-packages\yfinance\utils.py:104, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     101 logger.debug(f'Entering {func.__name__}()')
#     103 with IndentationContext():
# --> 104     result = func(*args, **kwargs)
#     106 logger.debug(f'Exiting {func.__name__}()')
#     107 return result
#
# File c:\Users\tkhrs\anaconda3\envs\python311\Lib\site-packages\yfinance\data.py:335, in YfData.get(self, url, user_agent_headers, params, proxy, timeout)
#     333 @utils.log_indent_decorator
#     334 def get(self, url, user_agent_headers=None, params=None, proxy=None, timeout=30):
# --> 335     return self._make_request(url, request_method = self._session.get, user_agent_headers=user_agent_headers, params=params, proxy=proxy, timeout=timeout)
#
# File c:\Users\tkhrs\anaconda3\envs\python311\Lib\site-packages\yfinance\utils.py:104, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     101 logger.debug(f'Entering {func.__name__}()')
#     103 with IndentationContext():
# --> 104     result = func(*args, **kwargs)
#     106 logger.debug(f'Exiting {func.__name__}()')
#     107 return result
#
# File c:\Users\tkhrs\anaconda3\envs\python311\Lib\site-packages\yfinance\data.py:397, in YfData._make_request(self, url, request_method, user_agent_headers, body, params, proxy, timeout)
#     395     # Raise exception if rate limited
#     396     if response.status_code == 429:
# --> 397         raise YFRateLimitError()
#     399 return response
#
# YFRateLimitError: Too Many Requests. Rate limited. Try after a while.

# %% [markdown]
# 2.それぞれ機能を解説

# %% [markdown]
# 2.0ライブラリインストール

# %%
# !pip install streamlit
# !pip install pandas
# !pip install yfinance==0.2.40
# !pip install altair
# Out:
# Requirement already satisfied: streamlit in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (1.41.1)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from streamlit) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from streamlit) (8.1.8)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: packaging<25,>=20 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from streamlit) (11.1.0)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from streamlit) (5.29.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from streamlit) (19.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from streamlit) (13.9.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from streamlit) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from streamlit) (6.4.2)
# Requirement already satisfied: jinja2 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.5)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from altair<6,>=4.0->streamlit) (1.24.1)
# Requirement already satisfied: colorama in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from requests<3,>=2.27->streamlit) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.19.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.22.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Requirement already satisfied: pandas in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from pandas) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: yfinance==0.2.40 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (0.2.40)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from yfinance==0.2.40) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from yfinance==0.2.40) (2.2.3)
# Requirement already satisfied: requests>=2.31 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from yfinance==0.2.40) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from yfinance==0.2.40) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from yfinance==0.2.40) (5.3.1)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from yfinance==0.2.40) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from yfinance==0.2.40) (2025.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from yfinance==0.2.40) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from yfinance==0.2.40) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from yfinance==0.2.40) (4.13.3)
# Requirement already satisfied: html5lib>=1.1 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from yfinance==0.2.40) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance==0.2.40) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance==0.2.40) (4.12.2)
# Requirement already satisfied: six>=1.9 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from html5lib>=1.1->yfinance==0.2.40) (1.17.0)
# Requirement already satisfied: webencodings in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from html5lib>=1.1->yfinance==0.2.40) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from pandas>=1.3.0->yfinance==0.2.40) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from pandas>=1.3.0->yfinance==0.2.40) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from requests>=2.31->yfinance==0.2.40) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from requests>=2.31->yfinance==0.2.40) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from requests>=2.31->yfinance==0.2.40) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from requests>=2.31->yfinance==0.2.40) (2025.1.31)
# Requirement already satisfied: altair in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (5.5.0)
# Requirement already satisfied: jinja2 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from altair) (3.1.5)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from altair) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from altair) (1.24.1)
# Requirement already satisfied: packaging in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from altair) (24.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from altair) (4.12.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from jsonschema>=3.0->altair) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from jsonschema>=3.0->altair) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from jsonschema>=3.0->altair) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from jsonschema>=3.0->altair) (0.22.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tkhrs\anaconda3\envs\python311\lib\site-packages (from jinja2->altair) (2.1.5)

# %%
import streamlit as st # フロントエンドを扱うstreamlitの機能をインポート
import pandas as pd # データフレームを扱う機能をインポート
import yfinance as yf # yahoo financeから株価情報を取得するための機能をインポート
import altair as alt # チャート可視化機能をインポート

print(f"yfinance version: {yf.__version__}") #yfinanceが0.2.40であることを確認
# Out:
# yfinance version: 0.2.40

# %% [markdown]
# 2.1株価取得

# %% [markdown]
# 具体例として、TOYOTAを参考に株価を取得します。
# 必要な情報は銘柄：7203.T だけです。
#
# yf.Ticker(ここ銘柄)で情報を取得できます。
# 可視化はtkr.history(period='ここ欲しい区間') で構造化データを取得できます。

# %%
tkr = yf.Ticker("7203.T")
hist = tkr.history(period='10d') 
display(hist)
# Out:
# Failed to get ticker '7203.T' reason: Expecting value: line 1 column 1 (char 0)
# $7203.T: possibly delisted; No price data found  (period=10d)
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %% [markdown]
# 数字だけでは、どの企業のデータかわからないので、カラムにTOYOTAの企業名を入れ、終値だけ取得します。

# %%
hist.index = hist.index.strftime('%d %B %Y') # indexを日付のフォーマットに変更
hist = hist[['Close']] # データを終値だけ抽出
hist.columns = ["TOYOTA"] # データのカラムをyf.Tickerのリクエストした企業名に設定
display(hist)
# Out:
#              TOYOTA
# Date
# 17 May 2023  1928.0
# 18 May 2023  1955.5
# 19 May 2023  1959.5
# 22 May 2023  1950.0
# 23 May 2023  1857.0
# 24 May 2023  1956.5
# 25 May 2023  1938.5
# 26 May 2023  1937.0
# 29 May 2023  1928.5
# 30 May 2023  1940.0

# %% [markdown]
# 注意点として、複数の株価データが日数が違うデータもindexであるDateに順番に格納されてしまうので、
# 対策として日付をカラムにします。
#
# .Tで転置ができます。

# %%
hist = hist.T # 欲しい情報が逆なので、転置する
hist.index.name = 'Name' # indexの名前をNameにする
display(hist)
# Out:
# Date    17 May 2023  18 May 2023  19 May 2023  22 May 2023  23 May 2023  \
# Name
# TOYOTA       1928.0       1955.5       1959.5       1950.0       1857.0
#
# Date    24 May 2023  25 May 2023  26 May 2023  29 May 2023  30 May 2023
# Name
# TOYOTA       1956.5       1938.5       1937.0       1928.5       1940.0

# %% [markdown]
# これで株価データの取得が完了しました。

# %% [markdown]
# 2.2チャートによる可視化

# %% [markdown]
# チャートにするために、構造化データを日付をx軸、株価をy軸に変更します。
# 複数のデータがあった方がわかりやすいので、チャートのための構造化データを以下のコードで作成します。

# %%
tickers = {
    'apple': 'AAPL',
    'facebook': 'META',
    'google': 'GOOGL',
    'microsoft': 'MSFT',
    'netflix': 'NFLX',
    'amazon': 'AMZN',
    'TOTO': '5332.T',
    'TOYOTA': '7203.T',
}

days = 10

df = pd.DataFrame() # 株価を代入するための空箱を用意

for company in tickers.keys():
    tkr = yf.Ticker(tickers[company]) # 設定した銘柄一覧でリクエストの為の7203.Tなどに変換をして、それをyf.Tickerで株価リクエスト
    hist = tkr.history(period=f'{days}d') # スライドバーで指定した日数で取得した情報を絞る
    hist.index = hist.index.strftime('%d %B %Y') # indexを日付のフォーマットに変更
    hist = hist[['Close']] # データを終値だけ抽出
    hist.columns = [company] # データのカラムをyf.Tickerのリクエストした企業名に設定
    hist = hist.T # 欲しい情報が逆なので、転置する
    hist.index.name = 'Name' # indexの名前をNameにする
    df = pd.concat([df, hist]) # 用意した空のデータフレームに設定したhistのデータを結合する

display(df)
# Out:
# Date       15 May 2023  16 May 2023  17 May 2023  18 May 2023  19 May 2023  \
# Name
# apple       172.070007   172.070007   172.690002   175.050003   175.160004
# facebook    238.860001   238.820007   242.490005   246.850006   245.639999
# google      116.510002   119.510002   120.839996   122.830002   122.760002
# microsoft   308.784973   311.059998   314.000000   318.519989   318.339996
# netflix     335.890015   333.750000   339.959991   371.290009   365.359985
# amazon      111.199997   113.400002   115.500000   118.150002   116.250000
# TOTO               NaN          NaN  4625.000000  4595.000000  4550.000000
# TOYOTA             NaN          NaN  1928.000000  1955.500000  1959.500000
#
# Date       22 May 2023  23 May 2023  24 May 2023  25 May 2023  26 May 2023  \
# Name
# apple       174.199997   171.559998   171.839996   172.990005   175.429993
# facebook    248.320007   246.740005   249.210007   252.690002   262.040009
# google      125.050003   122.559998   120.900002   123.480003   124.610001
# microsoft   321.179993   315.260010   313.850006   325.920013   332.890015
# netflix     363.010010   355.989990   364.850006   359.000000   378.880005
# amazon      115.010002   114.989998   116.750000   115.000000   120.110001
# TOTO       4600.000000  4475.000000  4335.000000  4280.000000  4295.000000
# TOYOTA     1950.000000  1857.000000  1956.500000  1938.500000  1937.000000
#
# Date       29 May 2023  30 May 2023
# Name
# apple              NaN          NaN
# facebook           NaN          NaN
# google             NaN          NaN
# microsoft          NaN          NaN
# netflix            NaN          NaN
# amazon             NaN          NaN
# TOTO            4285.0       4225.0
# TOYOTA          1928.5       1940.0

# %% [markdown]
# 構造化データを日付をx軸、株価をy軸するために転置します。

# %%
data = df # 全体像のコードと一致させるために変数名を変更します。
data = data.T.reset_index() # dataを抽出して転置
display(data)
# Out:
# Name         Date       apple    facebook      google   microsoft     netflix  \
# 0     15 May 2023  172.070007  238.860001  116.510002  308.784973  335.890015
# 1     16 May 2023  172.070007  238.820007  119.510002  311.059998  333.750000
# 2     17 May 2023  172.690002  242.490005  120.839996  314.000000  339.959991
# 3     18 May 2023  175.050003  246.850006  122.830002  318.519989  371.290009
# 4     19 May 2023  175.160004  245.639999  122.760002  318.339996  365.359985
# 5     22 May 2023  174.199997  248.320007  125.050003  321.179993  363.010010
# 6     23 May 2023  171.559998  246.740005  122.559998  315.260010  355.989990
# 7     24 May 2023  171.839996  249.210007  120.900002  313.850006  364.850006
# 8     25 May 2023  172.990005  252.690002  123.480003  325.920013  359.000000
# 9     26 May 2023  175.429993  262.040009  124.610001  332.890015  378.880005
# 10    29 May 2023         NaN         NaN         NaN         NaN         NaN
# 11    30 May 2023         NaN         NaN         NaN         NaN         NaN
#
# Name      amazon    TOTO  TOYOTA
# 0     111.199997     NaN     NaN
# 1     113.400002     NaN     NaN
# 2     115.500000  4625.0  1928.0
# 3     118.150002  4595.0  1955.5
# 4     116.250000  4550.0  1959.5
# 5     115.010002  4600.0  1950.0
# 6     114.989998  4475.0  1857.0
# 7     116.750000  4335.0  1956.5
# 8     115.000000  4280.0  1938.5
# 9     120.110001  4295.0  1937.0
# 10           NaN  4285.0  1928.5
# 11           NaN  4225.0  1940.0

# %% [markdown]
# バラバラのデータである必要がないので、企業を１つのカラムにまとめます。
# 使い方は以下のようになります。
#
# pd.melt(ここにデータ, id_vars=[変更した良くない列]).rename(
#     columns={'value': '新しいカラムの名前'}
# )

# %%
data = pd.melt(data, id_vars=['Date']).rename(
    columns={'value': 'Stock Prices'}
)
display(data)
# Out:
#            Date    Name  Stock Prices
# 0   15 May 2023   apple    172.070007
# 1   16 May 2023   apple    172.070007
# 2   17 May 2023   apple    172.690002
# 3   18 May 2023   apple    175.050003
# 4   19 May 2023   apple    175.160004
# ..          ...     ...           ...
# 91  24 May 2023  TOYOTA   1956.500000
# 92  25 May 2023  TOYOTA   1938.500000
# 93  26 May 2023  TOYOTA   1937.000000
# 94  29 May 2023  TOYOTA   1928.500000
# 95  30 May 2023  TOYOTA   1940.000000
#
# [96 rows x 3 columns]

# %% [markdown]
# 2.2チャートによる可視化

# %% [markdown]
# alt.Chartを使って、チャートデータを作成します。
# 指定している設定は以下のようになります。
#
# - チャートに使うデータをdata
# - xのラベルにDate　色種類は:T
# - yのラベルにStock Prices　色種類は:Q　範囲0, 3000
# - 全体の色種類指定:N

# %%
chart = (
    alt.Chart(data)
    .mark_line(opacity=0.8, clip=True)
    .encode(
        x="Date:T",
        y=alt.Y("Stock Prices:Q", stack=None, scale=alt.Scale(domain=[0, 3000])),
        color='Name:N'
    )
)

# 作成したチャートをstreamlitで表示
display(chart)
# Out:
# alt.Chart(...)

# %% [markdown]
# 以上がアプリの動作部分です。

# %% [markdown]
# >streamlitに実装する場合の使う機能

# %% [markdown]
# 今はユーザーがブラウザ上で選択したりなど、想定していませんが、
# 選択肢の表示などのコンポーネントを紹介します。
#
# ※streamlitはjupyterでは動作せず、実行ファイルでのみ動作します

# %% [markdown]
# タイトルは
# st.title("ここにタイトル")

# %% [markdown]
# ただの表示は
# st.write("ここに表示したい文字")
#
# ただし、再読み込みしない限り、この表示された文字は変更されません。

# %% [markdown]
# 選択肢は  st.selectbox("ここに表示したい項目名",ここに配列のデータ)
# でできます。

# %% [markdown]
# サイドバーに配置したい場合は、
# st.slider.write("ここに表示したい文字")のように.sliderをstのうしろにつけます。

# %% [markdown]
# スライドバーの表示は
# st.sidebar.slider('ここに表示したい文字', 最小値の数字, 最大値の数字, 初期の位置の値)
# でできます。

# %% [markdown]
# チャートの表示は
# st.altair_chart(ここにちゃーとのデータ, use_container_width=True)でできます。

# %% [markdown]
# 以上の機能を使ってwebアプリにしていきます。

# %% [markdown]
# >（演習）streamlitに実装しましょう！

# %% [markdown]
# 手元で動いたアプリをstreamlitで動くようにします。
# この演習では必ず実行ファイルにコーディングしてください。

# %% [markdown]
# ※streamlit run ファイル名で実行する時は必ず実行ファイル(.py)で実行してください。

# %% [markdown]
# 実装の流れ
# 1. 取得した全株価から抽出する条件companiesの内容をセレクターで取得
#     1. 構造化データから選択肢抽出
#     1. companiesにセレクトボックスの値が入るようにする
# 1. 固定数字をスライドバーで変数へ
# 1. ターミナルに出力していた文字などをブラウザに出力

# %% [markdown]
# 以下の手元で動いたコードをstreamlitで動くようにします。

# %%
import streamlit as st # フロントエンドを扱うstreamlitの機能をインポート
import pandas as pd # データフレームを扱う機能をインポート
import yfinance as yf # yahoo financeから株価情報を取得するための機能をインポート
import altair as alt # チャート可視化機能をインポート

#取得する銘柄の名前とキーを変換する一覧を設定
#東証などのシンボルはhttps://support.yahoo-net.jp/PccFinance/s/article/H000006603で検索できる
tickers = {
    'apple': 'AAPL',
    'facebook': 'META',
    'google': 'GOOGL',
    'microsoft': 'MSFT',
    'netflix': 'NFLX',
    'amazon': 'AMZN',
    'TOTO': '5332.T',
    'TOYOTA': '7203.T',
}

print('株価可視化アプリ')
print("こちらは株価可視化ツールです。以下のオプションから表示日数を指定できます。")# サイドバーに表示
print("表示日数選択") # サイドバーに表示

days = 10 # 取得するための日数daysに代入

print(f"過去 {days}日間 の株価") # 取得する日数を表示


def get_data(days, tickers):
    df = pd.DataFrame() # 株価を代入するための空箱を用意

    # 選択した株価の数だけ yf.Tickerでリクエストしてデータを取得する
    for company in tickers.keys():
        tkr = yf.Ticker(tickers[company]) # 設定した銘柄一覧でリクエストの為の7203.Tなどに変換をして、それをyf.Tickerで株価リクエスト
        hist = tkr.history(period=f'{days}d') # スライドバーで指定した日数で取得した情報を絞る
        hist.index = hist.index.strftime('%d %B %Y') # indexを日付のフォーマットに変更
        hist = hist[['Close']] # データを終値だけ抽出
        hist.columns = [company] # データのカラムをyf.Tickerのリクエストした企業名に設定
        hist = hist.T # 欲しい情報が逆なので、転置する
        hist.index.name = 'Name' # indexの名前をNameにする
        df = pd.concat([df, hist]) # 用意した空のデータフレームに設定したhistのデータを結合する
    return df # 返り値としてdfを返す

df = get_data(days, tickers) # リクエストする企業一覧すべてと変換するtickersを引数に株価取得





# 企業名の配列を生成し、companiesに代入
companies = ['google', 'apple','TOYOTA']

data = df.loc[companies] # 取得したデータから抽出するための配列で絞ってdataに代入
print("株価 ", data.sort_index()) # dataにあるindexを表示
data = data.T.reset_index() # dataを抽出して転置

# 企業ごとの別々のカラムにデータを表示する必要ないので企業を１つのカラムに統一
data = pd.melt(data, id_vars=['Date']).rename(
    columns={'value': 'Stock Prices'}
)


# チャートに表示する範囲、それぞれをymin, ymaxに代入
print("株価の範囲指定") # サイドバーに表示
ymin = 0
ymax = 3000

# dataとスライドバーで設定した最大最小値を元にalt.Chartを使って株価チャートを作成
chart = (
    alt.Chart(data)
    .mark_line(opacity=0.8, clip=True)
    .encode(
        x="Date:T",
        y=alt.Y("Stock Prices:Q", stack=None, scale=alt.Scale(domain=[ymin, ymax])),
        color='Name:N'
    )
)

# 作成したチャートをstreamlitで表示
display(chart)

# %% [markdown]
# 1.取得した全株価から抽出する条件companiesの内容をセレクターで取得

# %% [markdown]
# df.indexで構造化データから取得した企業のリストを取得できるので、これをlist関数を使って配列にする。

# %%
list(df.index)
# Out:
# ['apple',
#  'facebook',
#  'google',
#  'microsoft',
#  'netflix',
#  'amazon',
#  'TOTO',
#  'TOYOTA']

# %% [markdown]
# セレクトボックスの値をcompaniesに代入する。
#
# 使い方は
# st.selectbox("ここに表示したい項目名",ここに配列のデータ,初期で選択されている配列)
#
# 初期で選択されている配列はどれでも構いませんが、ここでは['google', 'apple','TOYOTA']を指定しておきます。

# %%
companies = st.multiselect(
    '会社名を選択してください。',
    list(df.index),
    ['google', 'apple','TOYOTA'],
)

# %% [markdown]
# 2.固定数字をスライドバーで変数へ

# %% [markdown]
# 10日で固定しているdaysとチャートの表示範囲ymin,ymaxをスライドバーから取得します。
# 変更する固定数字は以下の３つです。

# %%
days = 10

ymin = 0
ymax = 3000

# %% [markdown]
# スライドバーの使い方は以下のようになります。
# st.slider('ここに表示したい文字', 最小値の数字, 最大値の数字, 初期の位置の値)
#
# また１つのスライドバーから２つの値を取得する場合は、
#
# 小さい方の数字, 大きいの方の数字 = st.sidebar.slider(
#     'ここに表示したい文字',
#     最小値の数字, 最大値の数字, (最小値の数字, 最大値の数字)
# )
#
# でできます。

# %%
days = st.sidebar.slider('日数', 1, 50, 20)

ymin, ymax = st.slider(
    '範囲を指定してください。',
    0.0, 5000.0, (0.0, 5000.0)
)

# %% [markdown]
# streamlitに実装したアプリをまとめると、以下のようになります。

# %%
import streamlit as st # フロントエンドを扱うstreamlitの機能をインポート
import pandas as pd # データフレームを扱う機能をインポート
import yfinance as yf # yahoo financeから株価情報を取得するための機能をインポート
import altair as alt # チャート可視化機能をインポート

#取得する銘柄の名前とキーを変換する一覧を設定
#東証などのシンボルはhttps://support.yahoo-net.jp/PccFinance/s/article/H000006603で検索できる
tickers = {
    'apple': 'AAPL',
    'facebook': 'META',
    'google': 'GOOGL',
    'microsoft': 'MSFT',
    'netflix': 'NFLX',
    'amazon': 'AMZN',
    'TOTO': '5332.T',
    'TOYOTA': '7203.T',
}

print('株価可視化アプリ')
print("こちらは株価可視化ツールです。以下のオプションから表示日数を指定できます。")# サイドバーに表示
print("表示日数選択") # サイドバーに表示

days = st.sidebar.slider('日数', 1, 50, 20) # 取得するための日数daysに代入

print(f"過去 {days}日間 の株価") # 取得する日数を表示


def get_data(days, tickers):
    df = pd.DataFrame() # 株価を代入するための空箱を用意

    # 選択した株価の数だけ yf.Tickerでリクエストしてデータを取得する
    for company in tickers.keys():
        tkr = yf.Ticker(tickers[company]) # 設定した銘柄一覧でリクエストの為の7203.Tなどに変換をして、それをyf.Tickerで株価リクエスト
        hist = tkr.history(period=f'{days}d') # スライドバーで指定した日数で取得した情報を絞る
        hist.index = hist.index.strftime('%d %B %Y') # indexを日付のフォーマットに変更
        hist = hist[['Close']] # データを終値だけ抽出
        hist.columns = [company] # データのカラムをyf.Tickerのリクエストした企業名に設定
        hist = hist.T # 欲しい情報が逆なので、転置する
        hist.index.name = 'Name' # indexの名前をNameにする
        df = pd.concat([df, hist]) # 用意した空のデータフレームに設定したhistのデータを結合する
    return df # 返り値としてdfを返す

df = get_data(days, tickers) # リクエストする企業一覧すべてと変換するtickersを引数に株価取得





# 企業名の配列を生成し、companiesに代入
companies = st.multiselect(
    '会社名を選択してください。',
    list(df.index),
    ['google', 'apple','TOYOTA'],
)

data = df.loc[companies] # 取得したデータから抽出するための配列で絞ってdataに代入
print("株価 ", data.sort_index()) # dataにあるindexを表示
data = data.T.reset_index() # dataを抽出して転置

# 企業ごとの別々のカラムにデータを表示する必要ないので企業を１つのカラムに統一
data = pd.melt(data, id_vars=['Date']).rename(
    columns={'value': 'Stock Prices'}
)


# チャートに表示する範囲、それぞれをymin, ymaxに代入
print("株価の範囲指定") # サイドバーに表示


ymin, ymax = st.slider(
    '範囲を指定してください。',
    0.0, 5000.0, (0.0, 5000.0)
)

# dataとスライドバーで設定した最大最小値を元にalt.Chartを使って株価チャートを作成
chart = (
    alt.Chart(data)
    .mark_line(opacity=0.8, clip=True)
    .encode(
        x="Date:T",
        y=alt.Y("Stock Prices:Q", stack=None, scale=alt.Scale(domain=[ymin, ymax])),
        color='Name:N'
    )
)

# 作成したチャートをstreamlitで表示
display(chart)

# %% [markdown]
# 3.ターミナルに出力していた文字などをブラウザに出力

# %% [markdown]
# 最後にprintでターミナルで出力していた
# タイトルや文字やチャートを以下の４つのコードを使ってブラウザに出力します。
#
# - st.title
# - st.write
# - st.altair_chart

# %%
import streamlit as st # フロントエンドを扱うstreamlitの機能をインポート
import pandas as pd # データフレームを扱う機能をインポート
import yfinance as yf # yahoo financeから株価情報を取得するための機能をインポート
import altair as alt # チャート可視化機能をインポート

#取得する銘柄の名前とキーを変換する一覧を設定
#東証などのシンボルはhttps://support.yahoo-net.jp/PccFinance/s/article/H000006603で検索できる
tickers = {
    'apple': 'AAPL',
    'facebook': 'META',
    'google': 'GOOGL',
    'microsoft': 'MSFT',
    'netflix': 'NFLX',
    'amazon': 'AMZN',
    'TOTO': '5332.T',
    'TOYOTA': '7203.T',
}

st.title('株価可視化アプリ') # タイトル

st.write("こちらは株価可視化ツールです。以下のオプションから表示日数を指定できます。") # サイドバーに表示

st.write("表示日数選択") # サイドバーに表示

days = st.slider('日数', 1, 50, 20) # サイドバーに表示　取得するための日数をスライドバーで表示し、daysに代入

st.write(f"過去 {days}日間 の株価") # 取得する日数を表示

# @st.cache_dataで読み込みが早くなるように処理を保持しておける
@st.cache_data
def get_data(days, tickers):
    df = pd.DataFrame() # 株価を代入するための空箱を用意

    # 選択した株価の数だけ yf.Tickerでリクエストしてデータを取得する
    for company in tickers.keys():
        tkr = yf.Ticker(tickers[company]) # 設定した銘柄一覧でリクエストの為の7203.Tなどに変換をして、それをyf.Tickerで株価リクエスト
        hist = tkr.history(period=f'{days}d') # スライドバーで指定した日数で取得した情報を絞る
        hist.index = hist.index.strftime('%d %B %Y') # indexを日付のフォーマットに変更
        hist = hist[['Close']] # データを終値だけ抽出
        hist.columns = [company] # データのカラムをyf.Tickerのリクエストした企業名に設定
        hist = hist.T # 欲しい情報が逆なので、転置する
        hist.index.name = 'Name' # indexの名前をNameにする
        df = pd.concat([df, hist]) # 用意した空のデータフレームに設定したhistのデータを結合する
    return df # 返り値としてdfを返す

# チャートに表示する範囲をスライドで表示し、それぞれをymin, ymaxに代入
st.write("株価の範囲指定") # サイドバーに表示
ymin, ymax = st.slider(
    '範囲を指定してください。',
    0.0, 5000.0, (0.0, 5000.0)
) # サイドバーに表示

df = get_data(days, tickers) # リクエストする企業一覧すべてと変換するtickersを引数に株価取得


# 取得したデータから抽出するための配列を生成し、companiesに代入
companies = st.multiselect(
    '会社名を選択してください。',
    list(df.index),
    ['google', 'apple','TOYOTA'], # 最初に表示する企業名を設定
)


data = df.loc[companies] # 取得したデータから抽出するための配列で絞ってdataに代入
st.write("株価 ", data.sort_index()) # dataにあるindexを表示
data = data.T.reset_index() # dataを抽出して転置

# 企業ごとの別々のカラムにデータを表示する必要ないので企業を１つのカラムに統一
data = pd.melt(data, id_vars=['Date']).rename(
    columns={'value': 'Stock Prices'}
)

# dataとスライドバーで設定した最大最小値を元にalt.Chartを使って株価チャートを作成
chart = (
    alt.Chart(data)
    .mark_line(opacity=0.8, clip=True)
    .encode(
        x="Date:T",
        y=alt.Y("Stock Prices:Q", stack=None, scale=alt.Scale(domain=[ymin, ymax])),
        color='Name:N'
    )
)

# 作成したチャートをstreamlitで表示
st.altair_chart(chart, use_container_width=True)

# %% [markdown]
# 最後にサイドバーに表示する項目に.sidebarをつけます。

# %%
import streamlit as st # フロントエンドを扱うstreamlitの機能をインポート
import pandas as pd # データフレームを扱う機能をインポート
import yfinance as yf # yahoo financeから株価情報を取得するための機能をインポート
import altair as alt # チャート可視化機能をインポート

#取得する銘柄の名前とキーを変換する一覧を設定
#東証などのシンボルはhttps://support.yahoo-net.jp/PccFinance/s/article/H000006603で検索できる
tickers = {
    'apple': 'AAPL',
    'facebook': 'META',
    'google': 'GOOGL',
    'microsoft': 'MSFT',
    'netflix': 'NFLX',
    'amazon': 'AMZN',
    'TOTO': '5332.T',
    'TOYOTA': '7203.T',
}

st.title('株価可視化アプリ') # タイトル

st.sidebar.write("こちらは株価可視化ツールです。以下のオプションから表示日数を指定できます。") # サイドバーに表示

st.sidebar.write("表示日数選択") # サイドバーに表示

days = st.sidebar.slider('日数', 1, 50, 20) # サイドバーに表示　取得するための日数をスライドバーで表示し、daysに代入

st.write(f"過去 {days}日間 の株価") # 取得する日数を表示

# @st.cache_dataで読み込みが早くなるように処理を保持しておける
@st.cache_data
def get_data(days, tickers):
    df = pd.DataFrame() # 株価を代入するための空箱を用意

    # 選択した株価の数だけ yf.Tickerでリクエストしてデータを取得する
    for company in tickers.keys():
        tkr = yf.Ticker(tickers[company]) # 設定した銘柄一覧でリクエストの為の7203.Tなどに変換をして、それをyf.Tickerで株価リクエスト
        hist = tkr.history(period=f'{days}d') # スライドバーで指定した日数で取得した情報を絞る
        hist.index = hist.index.strftime('%d %B %Y') # indexを日付のフォーマットに変更
        hist = hist[['Close']] # データを終値だけ抽出
        hist.columns = [company] # データのカラムをyf.Tickerのリクエストした企業名に設定
        hist = hist.T # 欲しい情報が逆なので、転置する
        hist.index.name = 'Name' # indexの名前をNameにする
        df = pd.concat([df, hist]) # 用意した空のデータフレームに設定したhistのデータを結合する
    return df # 返り値としてdfを返す

# チャートに表示する範囲をスライドで表示し、それぞれをymin, ymaxに代入
st.sidebar.write("株価の範囲指定") # サイドバーに表示
ymin, ymax = st.sidebar.slider(
    '範囲を指定してください。',
    0.0, 5000.0, (0.0, 5000.0)
) # サイドバーに表示

df = get_data(days, tickers) # リクエストする企業一覧すべてと変換するtickersを引数に株価取得


# 取得したデータから抽出するための配列を生成し、companiesに代入
companies = st.multiselect(
    '会社名を選択してください。',
    list(df.index),
    ['google', 'apple','TOYOTA'], # 最初に表示する企業名を設定
)


data = df.loc[companies] # 取得したデータから抽出するための配列で絞ってdataに代入
st.write("株価 ", data.sort_index()) # dataにあるindexを表示
data = data.T.reset_index() # dataを抽出して転置

# 企業ごとの別々のカラムにデータを表示する必要ないので企業を１つのカラムに統一
data = pd.melt(data, id_vars=['Date']).rename(
    columns={'value': 'Stock Prices'}
)

# dataとスライドバーで設定した最大最小値を元にalt.Chartを使って株価チャートを作成
chart = (
    alt.Chart(data)
    .mark_line(opacity=0.8, clip=True)
    .encode(
        x="Date:T",
        y=alt.Y("Stock Prices:Q", stack=None, scale=alt.Scale(domain=[ymin, ymax])),
        color='Name:N'
    )
)

# 作成したチャートをstreamlitで表示
st.altair_chart(chart, use_container_width=True)
